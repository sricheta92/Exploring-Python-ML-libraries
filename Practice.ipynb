# %%
# %matplotlib inline
import matplotlib.pyplot as plt;
year = [1970,1980,1990,2000];
pop = [1.3,2.7,7.8,9.0];
plt.plot(year,pop);
plt.show();

# %%
# %matplotlib inline
import matplotlib.pyplot as plt;
year = [1970,1980,1990,2000];
pop = [1.3,2.7,7.8,9.0];
plt.scatter(year,pop);
plt.show();

# %%
# %matplotlib inline
import matplotlib.pyplot as plt;
year = [1970,1980,1990,2000];
pop = [1.3,2.7,7.8,9.0];
plt.plot(year,pop);
plt.xlabel("Year");
plt.ylabel("Population");
plt.show();

# %%
import pandas as pd;
pd.read_csv("C:/Users/Sricheta's computer/Downloads/movies.csv")
# Out:
#                                           Title    Year  \
# 0                                    127 Hours   2010.0
# 1                                  3 Backyards   2010.0
# 2                                            3   2010.0
# 3                    8: The Mormon Proposition   2010.0
# 4          A Turtle's Tale: Sammy's Adventures   2010.0
# 5                          Alice in Wonderland   2010.0
# 6                          Alice in Wonderland   2010.0
# 7                              All Good Things   2010.0
# 8                              Alpha and Omega   2010.0
# 9                                        Amigo   2010.0
# 10                            Anderson's Cross   2010.0
# 11                              Animals United   2010.0
# 12                                Another Year   2010.0
# 13                            Barney's Version   2010.0
# 14                                Barry Munday   2010.0
# 15                                   Beginners   2010.0
# ...

# %%
import pandas as pd;
movies = pd.read_csv("C:/Users/Sricheta's computer/Downloads/movies.csv")
movies.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score', 'Unnamed: 25'],
#       dtype='object')

# %%
movies.dtypes
# Out:
# Title                           object
# Year                           float64
# Genres                          object
# Language                        object
# Country                         object
# Content Rating                  object
# Duration                       float64
# Aspect Ratio                   float64
# Budget                         float64
# Gross Earnings                 float64
# Director                        object
# Actor 1                         object
# Actor 2                         object
# Actor 3                         object
# Facebook Likes - Director      float64
# Facebook Likes - Actor 1       float64
# Facebook Likes - Actor 2       float64
# Facebook Likes - Actor 3       float64
# Facebook Likes - cast Total      int64
# Facebook likes - Movie           int64
# Facenumber in posters          float64
# User Votes                       int64
# Reviews by Users               float64
# Reviews by Crtiics             float64
# ...

# %% [markdown]
# movies["Year"]

# %%
moviesYear = movies['Year'];

# %%
moviesYear.head()
# Out:
# 0    2010.0
# 1    2010.0
# 2    2010.0
# 3    2010.0
# 4    2010.0
# Name: Year, dtype: float64

# %%
subset = movies[['Title','Genres','Language']].loc[0];
subset.head()
# Out:
# Title                               127 Hours
# Genres      Adventure|Biography|Drama|Thriller
# Language                               English
# Name: 0, dtype: object

# %%
subset1 = movies.loc[0]
print(subset1)
# Out:
# Title                                                  127 Hours
# Year                                                         2010
# Genres                         Adventure|Biography|Drama|Thriller
# Language                                                  English
# Country                                                       USA
# Content Rating                                                  R
# Duration                                                       94
# Aspect Ratio                                                 1.85
# Budget                                                    1.8e+07
# Gross Earnings                                        1.83295e+07
# Director                                              Danny Boyle
# Actor 1                                              James Franco
# Actor 2                                            Treat Williams
# Actor 3                                               Kate Burton
# ...

# %%
movies.loc[0]
# Out:
# Title                                                  127 Hours
# Year                                                         2010
# Genres                         Adventure|Biography|Drama|Thriller
# Language                                                  English
# Country                                                       USA
# Content Rating                                                  R
# Duration                                                       94
# Aspect Ratio                                                 1.85
# Budget                                                    1.8e+07
# Gross Earnings                                        1.83295e+07
# Director                                              Danny Boyle
# Actor 1                                              James Franco
# Actor 2                                            Treat Williams
# Actor 3                                               Kate Burton
# ...

# %%
movies.shape
# Out:
# (1604, 26)

# %%
movies.shape[0]
# Out:
# 1604

# %%
movies.iloc

# %%
movies.loc[1]
# Out:
# Title                             3 Backyards
# Year                                      2010
# Genres                                   Drama
# Language                               English
# Country                                    USA
# Content Rating                               R
# Duration                                    88
# Aspect Ratio                               NaN
# Budget                                  300000
# Gross Earnings                             NaN
# Director                       Eric Mendelsohn
# Actor 1                         Embeth Davidtz
# Actor 2                             Edie Falco
# Actor 3                           Kathryn Erbe
# Facebook Likes - Director                    5
# Facebook Likes - Actor 1                   795
# Facebook Likes - Actor 2                   659
# Facebook Likes - Actor 3                   301
# Facebook Likes - cast Total               1884
# Facebook likes - Movie                      92
# ...

# %%
movies.iloc[1]
# Out:
# Title                             3 Backyards
# Year                                      2010
# Genres                                   Drama
# Language                               English
# Country                                    USA
# Content Rating                               R
# Duration                                    88
# Aspect Ratio                               NaN
# Budget                                  300000
# Gross Earnings                             NaN
# Director                       Eric Mendelsohn
# Actor 1                         Embeth Davidtz
# Actor 2                             Edie Falco
# Actor 3                           Kathryn Erbe
# Facebook Likes - Director                    5
# Facebook Likes - Actor 1                   795
# Facebook Likes - Actor 2                   659
# Facebook Likes - Actor 3                   301
# Facebook Likes - cast Total               1884
# Facebook likes - Movie                      92
# ...

# %%
movies.groupby('Year').mean().plot()

# %%
import numpy as np;
a = np.c_[np.array([[1,2],[3,4]])
print(a)
np.c_?
# Out:
# [[1 2]
#  [3 4]]
